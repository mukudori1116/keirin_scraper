# %%
import pandas

# %%
fetched_dataframes = pandas.io.html.read_html('https://keirin.kdreams.jp/nara/racedetail/5320141231020001/?pageType=showResult')
fetched_dataframes[0]
# Out:
#        0    1    2    3                 4                 5    6     7   \
# 0      予想  好気合   総評   枠番                車番       選手名府県/年齢/期別   級班    脚質
# 1    競走得点    S    B    逃                 捲                 差    マ    1着
# 2     NaN  NaN  NaN    1                 1  後田 康成  長　崎/41/75   A2     追
# 3     NaN  NaN  NaN    2                 2  千澤 大輔  青　森/27/95   A1     両
# 4     NaN  NaN  NaN    3                 3  山村 慮太  大　阪/28/97   A2     逃
# 5     NaN  NaN  NaN    4                 4  田村 博之  徳　島/45/69   A2     追
# 6     NaN  NaN  NaN    5   緒方 剛  埼　玉/31/92                A2    両  3.92
# 7     NaN  NaN  NaN    5                 6   米山 潤  千　葉/35/88   A2     逃
# 8     NaN  NaN  NaN    7  長澤 道雄  兵　庫/43/65                A2    追  3.92
# 9     NaN  NaN  NaN    6                 8  田村 英輝  徳　島/39/78   A2     逃
# 10    NaN  NaN  NaN    9  白川 裕也  青　森/36/85                A1    追  3.92
# 11  【誘導員】  NaN  NaN  NaN               NaN               NaN  NaN   NaN
#
# ...

# %%
fetched_dataframes[0].ix[2,5]
# Out:
# '後田 康成  長\u3000崎/41/75'

# %%
fetched_dataframes[0].columns = ['id', '順位', 'コード', '市場', '名称', '時刻', '取引値', '発行済み株式数', '時価総額（百万円）', '単元株数', '掲示板', '順位', 'コード', '市場', '名称', '時刻', '取引値', '発行済み株式数', '時価総額（百万円）', '単元株数', '掲示板', '単元株数', '掲示板']

# %%
fetched_dataframes[0]
# Out:
#        id   順位  コード   市場                名称                時刻  取引値  発行済み株式数  \
# 0      予想  好気合   総評   枠番                車番       選手名府県/年齢/期別   級班       脚質
# 1    競走得点    S    B    逃                 捲                 差    マ       1着
# 2     NaN  NaN  NaN    1                 1  後田 康成  長　崎/41/75   A2        追
# 3     NaN  NaN  NaN    2                 2  千澤 大輔  青　森/27/95   A1        両
# 4     NaN  NaN  NaN    3                 3  山村 慮太  大　阪/28/97   A2        逃
# 5     NaN  NaN  NaN    4                 4  田村 博之  徳　島/45/69   A2        追
# 6     NaN  NaN  NaN    5   緒方 剛  埼　玉/31/92                A2    両     3.92
# 7     NaN  NaN  NaN    5                 6   米山 潤  千　葉/35/88   A2        逃
# 8     NaN  NaN  NaN    7  長澤 道雄  兵　庫/43/65                A2    追     3.92
# 9     NaN  NaN  NaN    6                 8  田村 英輝  徳　島/39/78   A2        逃
# 10    NaN  NaN  NaN    9  白川 裕也  青　森/36/85                A1    追     3.92
# ...

# %%
col_names = [ 'c{}'.format(i) for i in range(22) ]
df = pandas.io.html.read_html('https://keirin.kdreams.jp/nara/racedetail/5320141231020001/?pageType=showResult', index_col=col_names)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ddeb96f97927> in <module>()
#       1 col_names = [ 'c{0:02d}'.format(i) for i in range(22) ]
# ----> 2 df = pandas.io.html.read_html('https://keirin.kdreams.jp/nara/racedetail/5320141231020001/?pageType=showResult', index_col=col_names)
#       3 df
#
# C:\Anaconda\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     894                   thousands=thousands, attrs=attrs, encoding=encoding,
#     895                   decimal=decimal, converters=converters, na_values=na_values,
# --> 896                   keep_default_na=keep_default_na)
#
# C:\Anaconda\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
# ...
