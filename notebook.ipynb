# %%
import pandas

# %%
fetched_dataframes = pandas.io.html.read_html('https://keirin.kdreams.jp/nara/racedetail/5320141231020001/?pageType=showResult')
fetched_dataframes[0]
# Out:
#        0    1    2    3                 4                 5    6     7   \
# 0      予想  好気合   総評   枠番                車番       選手名府県/年齢/期別   級班    脚質
# 1    競走得点    S    B    逃                 捲                 差    マ    1着
# 2     NaN  NaN  NaN    1                 1  後田 康成  長　崎/41/75   A2     追
# 3     NaN  NaN  NaN    2                 2  千澤 大輔  青　森/27/95   A1     両
# 4     NaN  NaN  NaN    3                 3  山村 慮太  大　阪/28/97   A2     逃
# 5     NaN  NaN  NaN    4                 4  田村 博之  徳　島/45/69   A2     追
# 6     NaN  NaN  NaN    5   緒方 剛  埼　玉/31/92                A2    両  3.92
# 7     NaN  NaN  NaN    5                 6   米山 潤  千　葉/35/88   A2     逃
# 8     NaN  NaN  NaN    7  長澤 道雄  兵　庫/43/65                A2    追  3.92
# 9     NaN  NaN  NaN    6                 8  田村 英輝  徳　島/39/78   A2     逃
# 10    NaN  NaN  NaN    9  白川 裕也  青　森/36/85                A1    追  3.92
# 11  【誘導員】  NaN  NaN  NaN               NaN               NaN  NaN   NaN
#
# ...

# %%
fetched_dataframes[0].ix[2,5]
# Out:
# '後田 康成  長\u3000崎/41/75'

# %%
fetched_dataframes[0].columns = ['id', '順位', 'コード', '市場', '名称', '時刻', '取引値', '発行済み株式数', '時価総額（百万円）', '単元株数', '掲示板', '順位', 'コード', '市場', '名称', '時刻', '取引値', '発行済み株式数', '時価総額（百万円）', '単元株数', '掲示板', '単元株数', '掲示板']

# %%
fetched_dataframes[0]
# Out:
#        id   順位  コード   市場                名称                時刻  取引値  発行済み株式数  \
# 0      予想  好気合   総評   枠番                車番       選手名府県/年齢/期別   級班       脚質
# 1    競走得点    S    B    逃                 捲                 差    マ       1着
# 2     NaN  NaN  NaN    1                 1  後田 康成  長　崎/41/75   A2        追
# 3     NaN  NaN  NaN    2                 2  千澤 大輔  青　森/27/95   A1        両
# 4     NaN  NaN  NaN    3                 3  山村 慮太  大　阪/28/97   A2        逃
# 5     NaN  NaN  NaN    4                 4  田村 博之  徳　島/45/69   A2        追
# 6     NaN  NaN  NaN    5   緒方 剛  埼　玉/31/92                A2    両     3.92
# 7     NaN  NaN  NaN    5                 6   米山 潤  千　葉/35/88   A2        逃
# 8     NaN  NaN  NaN    7  長澤 道雄  兵　庫/43/65                A2    追     3.92
# 9     NaN  NaN  NaN    6                 8  田村 英輝  徳　島/39/78   A2        逃
# 10    NaN  NaN  NaN    9  白川 裕也  青　森/36/85                A1    追     3.92
# ...

# %%
df = pandas.read_html('https://keirin.kdreams.jp/nara/racedetail/5320141231020001/?pageType=showResult')
df[0].fillna(method='ffill', inplace=True)
df[0]
# Out:
#        0    1   2   3                 4                 5   6     7   \
# 0      予想  好気合  総評  枠番                車番       選手名府県/年齢/期別  級班    脚質
# 1    競走得点    S   B   逃                 捲                 差   マ    1着
# 2    競走得点    S   B   1                 1  後田 康成  長　崎/41/75  A2     追
# 3    競走得点    S   B   2                 2  千澤 大輔  青　森/27/95  A1     両
# 4    競走得点    S   B   3                 3  山村 慮太  大　阪/28/97  A2     逃
# 5    競走得点    S   B   4                 4  田村 博之  徳　島/45/69  A2     追
# 6    競走得点    S   B   5   緒方 剛  埼　玉/31/92                A2   両  3.92
# 7    競走得点    S   B   5                 6   米山 潤  千　葉/35/88  A2     逃
# 8    競走得点    S   B   7  長澤 道雄  兵　庫/43/65                A2   追  3.92
# 9    競走得点    S   B   6                 8  田村 英輝  徳　島/39/78  A2     逃
# 10   競走得点    S   B   9  白川 裕也  青　森/36/85                A1   追  3.92
# 11  【誘導員】    S   B   9  白川 裕也  青　森/36/85                A1   追  3.92
#
# ...

# %%
import scrapy

# %%
response = scrapy.Request('https://keirin.kdreams.jp/nara/racedetail/5320141231020002/')
for player in response.css('tr.n1'):
    data_list = list(map(lambda x: x.strip(), player.css('td::text').extract()))
    print(data_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-94af1c8e1824> in <module>()
#       1 response = scrapy.Request('https://keirin.kdreams.jp/nara/racedetail/5320141231020002/')
# ----> 2 for player in response.css('tr.n1'):
#       3     data_list = list(map(lambda x: x.strip(), player.css('td::text').extract()))
#       4     print(data_list)
#
# AttributeError: 'Request' object has no attribute 'css'

# %%
import pandas

# %%
dfs = pandas.read_html("https://keirin.kdreams.jp/nara/racedetail/5320141231020002/")
dfs
# Out:
#                   0            1             2             3             4  \
# 0   1盛田 将人【北海道 92期】          NaN           NaN           NaN           NaN
# 1               NaN            2             3             4             5
# 2      黒田 大介愛　媛 77期  東 鉄也三　重 88期  菅原 洋輔岩　手 98期  取鳥 敬一岡　山 69期  中村 俊治山　口 54期
# 3                 2          NaN         306.0          92.2         565.2
# 4                 3        174.7           NaN         184.7         814.3
# 5                 4        152.5         387.4           NaN         500.4
# 6                 5        350.6         774.9         189.1           NaN
# 7                 6       2088.8        1264.3         980.4        1715.8
# 8                 7        842.8         774.9         393.8        1413.0
# 9                 8        425.1         828.3         153.0         842.8
# 10                9        304.0         335.9         182.6         727.9
#
#                5             6           7       8    9
# ...
